# %%
# Dependencies and Setup
import pandas as pd

# %%
from uszipcode import SearchEngine, SimpleZipcode
search = SearchEngine()

# %%
# cleaned year data files
year2018_path = "data/chicago_crimes_2018_cleaned.csv"
year2019_path = "data/chicago_crimes_2019_cleaned.csv"
year2020_path = "data/chicago_crimes_2020_cleaned.csv"
year2021_path = "data/chicago_crimes_2021_cleaned.csv"
year2022_path = "data/chicago_crimes_2022_cleaned.csv"

# Read the year data
year18 = pd.read_csv(year2018_path)
year19 = pd.read_csv(year2019_path)
year20 = pd.read_csv(year2020_path)
year21 = pd.read_csv(year2021_path)
year22 = pd.read_csv(year2022_path)

# %%
year18.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  11561837    JC110056  12/31/2018 11:59:00 PM         013XX W 72ND ST  1153
# 1  11556487    JC104662  12/31/2018 11:59:00 PM  112XX S SACRAMENTO AVE  1320
# 2  11552699    JC100043  12/31/2018 11:57:00 PM     084XX S SANGAMON ST  1310
# 3  11552724    JC100006  12/31/2018 11:56:00 PM      018XX S ALLPORT ST  0440
# 4  11552731    JC100031  12/31/2018 11:55:00 PM     078XX S SANGAMON ST  0486
#
#            Primary Type                           Description  \
# 0     THEFT (ALL TYPES)   FINANCIAL IDENTITY THEFT OVER $ 300
# 1  MINOR PROPERTY CRIME                            TO VEHICLE
# 2  MINOR PROPERTY CRIME                           TO PROPERTY
# 3     ASSAULT & BATTERY  AGG: HANDS/FIST/FEET NO/MINOR INJURY
# 4     ASSAULT & BATTERY               DOMESTIC BATTERY SIMPLE
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0                  NaN   False     False  ...   6.0              67        11
# 1               STREET   False     False  ...  19.0              74        14
# 2            APARTMENT   False     False  ...  21.0              71        14
# 3                OTHER    True     False  ...  25.0              31       08B
# 4            APARTMENT   False     False  ...  17.0              71       08B
#
#    X Coordinate Y Coordinate  Year              Updated On   Latitude  \
# 0     1168573.0    1857018.0  2018  01/17/2019 02:26:36 PM  41.763181
# 1     1158309.0    1829936.0  2018  01/10/2019 03:16:50 PM  41.689079
# 2     1171454.0    1848783.0  2018  01/10/2019 03:16:50 PM  41.740521
# 3     1168327.0    1891230.0  2018  01/10/2019 03:16:50 PM  41.857068
# 4     1171332.0    1852934.0  2018  01/10/2019 03:16:50 PM  41.751914
#
#    Longitude                       Location
# 0 -87.657709  (41.763181359, -87.657709477)
# 1 -87.696064  (41.689078832, -87.696064026)
# 2 -87.647391  (41.740520866, -87.647390719)
# 3 -87.657625  (41.857068095, -87.657625201)
# 4 -87.647717   (41.75191443, -87.647716532)
#
# [5 rows x 22 columns]

# %%
year19.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11864018    JC476123  09/24/2019 08:00:00 AM  022XX S MICHIGAN AVE  1154
# 1  11859805    JC471592  10/13/2019 08:30:00 PM   024XX W CHICAGO AVE  0860
# 2  11863808    JC476236  10/05/2019 06:30:00 PM     0000X N LOOMIS ST  0810
# 3  11859727    JC471542  10/13/2019 07:00:00 PM    016XX W ADDISON ST  1320
# 4  11859656    JC471240  10/13/2019 02:10:00 PM      051XX N BROADWAY  0560
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 1               THEFT                             RETAIL THEFT
# 2               THEFT                                OVER $500
# 3     CRIMINAL DAMAGE                               TO VEHICLE
# 4             ASSAULT                                   SIMPLE
#
#            Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0  COMMERCIAL / BUSINESS OFFICE   False     False  ...   3.0              33
# 1            GROCERY FOOD STORE   False     False  ...  26.0              24
# 2                     RESIDENCE   False     False  ...  27.0              28
# 3                        STREET   False     False  ...  47.0               6
# 4                   GAS STATION   False     False  ...  47.0               3
#
#    FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0        11     1177560.0    1889548.0  2019  10/20/2019 03:56:02 PM
# 1        06     1160005.0    1905256.0  2019  10/20/2019 04:03:03 PM
# 2        06     1166986.0    1900306.0  2019  10/20/2019 03:56:02 PM
# 3        14     1164930.0    1923972.0  2019  10/20/2019 04:03:03 PM
# 4       08A     1167380.0    1934505.0  2019  10/20/2019 04:03:03 PM
#
#     Latitude  Longitude                       Location
# 0  41.852248 -87.623786  (41.852248185, -87.623786256)
# 1  41.895732 -87.687784  (41.895732399, -87.687784384)
# 2  41.882002 -87.662287   (41.88200224, -87.662286977)
# 3  41.946987 -87.669164  (41.946987144, -87.669163602)
# 4  41.975838 -87.659854  (41.975837637, -87.659853835)
#
# [5 rows x 22 columns]

# %%
year20.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  12014684    JD189901  03/17/2020 09:30:00 PM  039XX N LECLAIRE AVE  0820
# 1  12012127    JD189186  03/18/2020 02:03:00 AM  039XX W JACKSON BLVD  0910
# 2  12012330    JD189367  03/18/2020 08:50:00 AM    023XX N KEELER AVE  0560
# 3  12014760    JD192130  03/18/2020 01:00:00 PM     047XX W MONROE ST  1150
# 4  12012667    JD189808  03/18/2020 05:35:00 PM    003XX S CICERO AVE  2017
#
#           Primary Type                    Description Location Description  \
# 0                THEFT                 $500 AND UNDER               STREET
# 1  MOTOR VEHICLE THEFT                     AUTOMOBILE            APARTMENT
# 2              ASSAULT                         SIMPLE            RESIDENCE
# 3   DECEPTIVE PRACTICE              CREDIT CARD FRAUD      OTHER (SPECIFY)
# 4            NARCOTICS  MANUFACTURE / DELIVER - CRACK             SIDEWALK
#
#    Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0   False     False  ...  45.0            15.0        06     1141659.0
# 1   False      True  ...  28.0            26.0        07     1150196.0
# 2   False     False  ...  35.0            20.0       08A     1147996.0
# 3   False     False  ...  28.0            25.0        11     1144749.0
# 4    True     False  ...  28.0            25.0        18     1144446.0
#
#   Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0    1925649.0  2020  03/25/2020 03:45:43 PM  41.952052 -87.754660
# 1    1898398.0  2020  03/25/2020 03:47:29 PM  41.877110 -87.723990
# 2    1915240.0  2020  03/25/2020 03:47:29 PM  41.923369 -87.731634
# 3    1899145.0  2020  03/25/2020 03:47:29 PM  41.879264 -87.743971
# 4    1898000.0  2020  03/25/2020 03:47:29 PM  41.876128 -87.745112
#
#                         Location
# 0  (41.952051946, -87.754660372)
# 1  (41.877110187, -87.723989719)
# 2  (41.923368973, -87.731633833)
# 3  (41.879264422, -87.743970898)
# 4  (41.876128106, -87.745112291)
#
# [5 rows x 22 columns]

# %%
year21.head()
# Out:
#          ID Case Number              Date                      Block  IUCR  \
# 0  12343475    JE202728   4/16/2021 20:45          056XX N RIDGE AVE   820
# 1  12602803    JF125633  10/21/2021 11:00   083XX S STONY ISLAND AVE  500E
# 2  12565821    JE475344  12/11/2021 20:00             077XX S MAY ST  1752
# 3  12540388    JE444591   11/14/2021 6:00  086XX S COTTAGE GROVE AVE   850
# 4  12541139    JE445494   11/14/2021 4:00            034XX W 38TH ST   486
#
#                  Primary Type  \
# 0                       THEFT
# 1               OTHER OFFENSE
# 2  OFFENSE INVOLVING CHILDREN
# 3                       THEFT
# 4                     BATTERY
#
#                                          Description Location Description  \
# 0                                     $500 AND UNDER      OTHER (SPECIFY)
# 1                                      EAVESDROPPING      OTHER (SPECIFY)
# 2  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER            RESIDENCE
# 3                                      ATTEMPT THEFT    CONVENIENCE STORE
# 4                            DOMESTIC BATTERY SIMPLE            RESIDENCE
#
#    Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0   False     False  ...  48.0              77         6           NaN
# 1   False     False  ...   8.0              45        26     1188260.0
# 2   False      True  ...  17.0              71        17     1169996.0
# 3   False     False  ...   6.0              44         6     1183071.0
# 4   False      True  ...  12.0              58       08B     1154073.0
#
#   Y Coordinate  Year        Updated On   Latitude  Longitude  \
# 0          NaN  2021   4/23/2021 16:51        NaN        NaN
# 1    1849805.0  2021   2/27/2022 15:46  41.742941 -87.585783
# 2    1853419.0  2021   9/27/2022 16:46  41.753274 -87.652598
# 3    1847869.0  2021  11/21/2021 15:48  41.737751 -87.604856
# 4    1879187.0  2021  11/21/2021 15:48  41.824317 -87.710266
#
#                         Location
# 0                            NaN
# 1   (41.74294124, -87.585783412)
# 2  (41.753274445, -87.652598299)
# 3  (41.737750767, -87.604855911)
# 4  (41.824316537, -87.710266215)
#
# [5 rows x 22 columns]

# %%
year22.head()
# Out:
#          ID Case Number              Date                     Block  IUCR  \
# 0  12648362    JF181248   3/16/2022 14:00     045XX S VINCENNES AVE  1130
# 1  13032945    JG212426  10/23/2022 12:00    006XX W IRVING PARK RD  2826
# 2  12713141    JF259485    5/29/2022 0:00  014XX S MUSEUM CAMPUS DR   870
# 3  13032436    JG211735    4/20/2022 0:01    039XX S CALIFORNIA AVE  1582
# 4  13032916    JG212285  12/14/2022 15:35           007XX E 40TH ST   890
#
#                  Primary Type                     Description  \
# 0          DECEPTIVE PRACTICE        FRAUD OR CONFIDENCE GAME
# 1               OTHER OFFENSE  HARASSMENT BY ELECTRONIC MEANS
# 2                       THEFT                  POCKET-PICKING
# 3  OFFENSE INVOLVING CHILDREN               CHILD PORNOGRAPHY
# 4                       THEFT                   FROM BUILDING
#
#                     Location Description  Arrest  Domestic  ...  Ward  \
# 0                              RESIDENCE   False     False  ...   3.0
# 1                              APARTMENT   False      True  ...  46.0
# 2                 SPORTS ARENA / STADIUM   False     False  ...   4.0
# 3  POLICE FACILITY / VEHICLE PARKING LOT   False     False  ...  12.0
# 4              SCHOOL - PRIVATE BUILDING   False     False  ...   4.0
#
#    Community Area  FBI Code  X Coordinate Y Coordinate  Year      Updated On  \
# 0              38        11     1180381.0    1874867.0  2022  4/6/2023 17:05
# 1               6        26           NaN          NaN  2022  4/6/2023 17:05
# 2              33         6           NaN          NaN  2022  6/5/2022 16:48
# 3              58        17           NaN          NaN  2022  4/6/2023 17:05
# 4              38         6           NaN          NaN  2022  4/6/2023 17:05
#
#     Latitude  Longitude                       Location
# 0  41.811898 -87.613884  (41.811898033, -87.613883795)
# 1        NaN        NaN                            NaN
# 2        NaN        NaN                            NaN
# 3        NaN        NaN                            NaN
# 4        NaN        NaN                            NaN
#
# [5 rows x 22 columns]

# %%
all_years  = pd.concat([year18, year19, year20, year21, year22], ignore_index=True, axis=0)

# Group crimes into like groups
all_years = all_years.replace({"KIDNAPPING" : "KIDNAPPING AND HUMAN TRAFFICKING", 
                                    "HUMAN TRAFFICKING" : "KIDNAPPING AND HUMAN TRAFFICKING",
                                    "NARCOTICS" : "DRUG RELATED",
                                    "OTHER NARCOTIC VIOLATION" : "DRUG RELATED",
                                    "ASSAULT": "ASSAULT & BATTERY",
                                    "BATTERY": "ASSAULT & BATTERY",
                                    "RITUALISM": "ASSAULT & BATTERY",
                                    "STALKING": "ASSAULT & BATTERY",
                                    "INTIMIDATION": "ASSAULT & BATTERY",
                                    "PUBLIC PEACE VIOLATION":"OTHER MINOR CRIMES",
                                    "INTERFERENCE WITH PUBLIC OFFICER":"OTHER MINOR CRIMES",
                                    "LIQUOR LAW VIOLATION":"OTHER MINOR CRIMES",
                                    "OBSCENITY":"OTHER MINOR CRIMES",
                                    "GAMBLING":"OTHER MINOR CRIMES",
                                    "NON-CRIMINAL":"OTHER MINOR CRIMES",
                                    "PUBLIC INDECENCY":"OTHER MINOR CRIMES",
                                    "OTHER OFFENSE":"OTHER MINOR CRIMES",
                                    "PROSTITUTION":"OTHER MINOR CRIMES",
                                    "THEFT":"THEFT (ALL TYPES)",
                                    "MOTOR VEHICLE THEFT":"THEFT (ALL TYPES)", 
                                    "ROBBERY":"THEFT (ALL TYPES)", 
                                    "BURGLARY":"THEFT (ALL TYPES)",
                                    "DECEPTIVE PRACTICE":"THEFT (ALL TYPES)",
                                    "CRIM SEXUAL ASSAULT": "SEXUAL RELATED CRIME",
                                    "CRIMINAL SEXUAL ASSAULT": "SEXUAL RELATED CRIME",
                                    "SEX OFFENSE": "SEXUAL RELATED CRIME",
                                    "CRIMINAL TRESPASS":"MINOR PROPERTY CRIME",
                                    "CRIMINAL DAMAGE":"MINOR PROPERTY CRIME",
                                    "WEAPONS VIOLATION":"WEAPONS RELATED CRIME",
                                    "CONCEALED CARRY LICENSE VIOLATION":"WEAPONS RELATED CRIME"})



# all_years.to_csv("chicago_crimes_all_cleaned.csv",index=False)



# all_years

# %%
# city_data_narrow_df = city_data_df[(city_data_df["Max Temp"]<=26) & (city_data_df["Max Temp"]>=21) & (city_data_df["Cloudiness"]==0)]
all_years2 = all_years.dropna(how = "any")



# all_years_test = all_years[(all_years["Latitude"].isnull)]
# all_years_test.count()

all_years2.count()
# Out:
# ID                      1163212
# Case Number             1163212
# Date                    1163212
# Block                   1163212
# IUCR                    1163212
# Primary Type            1163212
# Description             1163212
# Location Description    1163212
# Arrest                  1163212
# Domestic                1163212
# Beat                    1163212
# District                1163212
# Ward                    1163212
# Community Area          1163212
# FBI Code                1163212
# X Coordinate            1163212
# Y Coordinate            1163212
# Year                    1163212
# Updated On              1163212
# Latitude                1163212
# Longitude               1163212
# Location                1163212
# dtype: int64

# %%
# all_years2.to_csv("chicago_crimes_all_cleaned.csv",index=False)
